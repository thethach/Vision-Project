# %%
# %pip install torchvision --index-url https://download.pytorch.org/whl/cu118
# %pip install opencv-python
# %pip install opencv-contrib-python
# %pip install opencv-python torch
# %pip install opencv-python ultralytics
# %pip install git+https://github.com/openai/CLIP.git
# %pip install openai
# %pip install pyttsx3
# %pip install gTTS
# %pip install moviepy
# %pip install ffmpeg
# %pip install ultralytics gTTS ffmpeg-python

# %%
# %pip install ultralytics openai gtts torch torchvision opencv-python
# Out:
# Requirement already satisfied: ultralytics in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (8.3.119)
# Requirement already satisfied: openai in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (1.76.2)
# Requirement already satisfied: gtts in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (2.5.4)
# Requirement already satisfied: torch in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (2.7.0+cu118)
# Requirement already satisfied: torchvision in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (0.22.0+cu118)
# Requirement already satisfied: opencv-python in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.2.5)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\users\tyler\appdata\roaming\python\python312\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from gtts) (8.1.8)
# Requirement already satisfied: colorama in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from click<8.2,>=7.1->gtts) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: filelock in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from torch) (80.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tyler\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\tyler\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import cv2
import torch
import numpy as np
from ultralytics import YOLOWorld
from gtts import gTTS
from openai import OpenAI
import re

# ─── CONFIG ──────────────────────────────────────────────────────────
VIDEO_IN    = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk.mp4"
VIDEO_OUT   = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_annotated.mp4"
AUDIO_DIR   = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\audio_clips"
FINAL_AUDIO = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_audio.mp3"
TRANSCRIPT  = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_audio.txt"

MODEL_WEIGHTS = "yolov8x-worldv2.pt"
FRAME_SKIP    = 10        # process every Nth frame
CONF_THRESH   = 0.6      # YOLO confidence threshold
OPENAI_KEY    = "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" # your key
MAX_HAZARDS   = 150      # safeguard for CLIP text prompt length
# ──────────────────────────────────────────────────────────────────────

client = OpenAI(api_key=OPENAI_KEY)
spoken = {}

def speak_and_save(text: str, cooldown_s: float = 10.0):
    now = time.time()
    if now - spoken.get(text, 0) < cooldown_s:
        return None
    spoken[text] = now
    os.makedirs(AUDIO_DIR, exist_ok=True)
    out = os.path.join(AUDIO_DIR, f"{int(now)}.mp3")
    gTTS(text).save(out)
    return out

def fetch_hazard_list():
    resp = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role":"system","content":"List 100 common hazards/obstacles on a city sidewalk, comma-separated."},
            {"role":"user","content":"Generate 100 common hazards/obstacles for a pedestrian walking in a city."}
        ],
        temperature=0.7,
        max_tokens=300
    )
    txt = resp.choices[0].message.content
    items = re.split(r"[\n,]", txt)
    hazards = []
    for itm in items:
        h = re.sub(r"^\d+\.\s*", "", itm.strip())
        if h:
            hazards.append(h)
    return hazards[:MAX_HAZARDS]

def main():
    hazards = fetch_hazard_list()

    model = YOLOWorld(MODEL_WEIGHTS)
    model.conf = CONF_THRESH
    model.set_classes(hazards)

    cap = cv2.VideoCapture(VIDEO_IN)
    w, h = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out_vid = cv2.VideoWriter(VIDEO_OUT, fourcc, round(fps/FRAME_SKIP), (w, h))

    left_x, right_x, mid_y = w*0.25, w*0.75, h*0.5
    audio_paths, alert_texts = [], []
    frame_id = 0

    while True:
        ret, frame = cap.read()
        if not ret: break
        frame_id += 1
        if frame_id % FRAME_SKIP != 0: continue

        device = "cuda" if torch.cuda.is_available() else "cpu"
        res = model.predict(frame, conf=CONF_THRESH, device=device)[0]
        boxes = res.boxes.xyxy.cpu().numpy()
        confs = res.boxes.conf.cpu().numpy()
        cids  = res.boxes.cls.cpu().numpy()

        close_hazards = []
        light_states  = []

        # 1) Process each detection
        for (x1,y1,x2,y2), conf, cid in zip(boxes, confs, cids):
            name = res.names[int(cid)]
            cx, cy = (x1+x2)/2, (y1+y2)/2
            area_ratio = ((x2-x1)*(y2-y1)) / (w*h)

            # traffic signal logic
            if name == "traffic signal":
                crop = frame[int(y1):int(y2), int(x1):int(x2)]
                hsv  = cv2.cvtColor(crop, cv2.COLOR_BGR2HSV)

                # red mask
                lower_r1 = np.array([0,100,100]); upper_r1 = np.array([10,255,255])
                lower_r2 = np.array([160,100,100]); upper_r2 = np.array([180,255,255])
                red_mask = cv2.bitwise_or(
                    cv2.inRange(hsv, lower_r1, upper_r1),
                    cv2.inRange(hsv, lower_r2, upper_r2)
                )
                green_mask = cv2.inRange(hsv, np.array([35,100,100]), np.array([85,255,255]))
                state = "RED light" if cv2.countNonZero(red_mask) > cv2.countNonZero(green_mask) else "GREEN light"
                light_states.append(state)
                label = state
            else:
                label = name

            # “close” condition
            is_close = (cy > 0.7*h) or (area_ratio > 0.05)
            if is_close and name != "traffic signal":
                close_hazards.append(name)

            # draw
            color = (0,0,255) if is_close else (0,255,0)
            cv2.rectangle(frame, (int(x1),int(y1)), (int(x2),int(y2)), color, 2)
            cv2.putText(frame, f"{label} {conf:.2f}",
                        (int(x1), int(y1)-6),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)

        # 2) Generate alerts
        # Hazards
        if close_hazards:
            txt = "Alert: close hazards – " + ", ".join(dict.fromkeys(close_hazards))
            alert_texts.append(txt)
            p = speak_and_save(txt)
            if p: audio_paths.append(p)

        # Traffic lights
        if light_states:
            txt = "Traffic light state – " + ", ".join(dict.fromkeys(light_states))
            alert_texts.append(txt)
            p = speak_and_save(txt)
            if p: audio_paths.append(p)

        # 3) Draw H-split lines (blue)
        for (x0,y0,x1,y1) in [
            (int(left_x),0,int(left_x),h),
            (int(right_x),0,int(right_x),h),
            (int(left_x),int(mid_y),int(right_x),int(mid_y))
        ]:
            cv2.line(frame,(x0,y0),(x1,y1),(255,0,0),2)

        out_vid.write(frame)

    cap.release()
    out_vid.release()

    # 4) Merge all TTS mp3s
    if audio_paths:
        with open(FINAL_AUDIO, "wb") as fw:
            for mp3 in sorted(audio_paths):
                with open(mp3, "rb") as fr:
                    fw.write(fr.read())
    else:
        print("⚠️  No audio clips were generated, skipping final audio merge.")

    # 5) Write transcript
    with open(TRANSCRIPT, "w", encoding="utf-8") as tf:
        tf.write("\n".join(alert_texts))

    print("✅ Video:",      VIDEO_OUT)
    print("✅ Audio:",      FINAL_AUDIO)
    print("✅ Transcript:", TRANSCRIPT)

if __name__ == "__main__":
    main()
# Out:
# 0: 384x640 (no detections), 36.5ms
# Speed: 1.9ms preprocess, 36.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.3ms
# Speed: 2.9ms preprocess, 33.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.7ms
# Speed: 1.8ms preprocess, 32.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.3ms
# Speed: 3.3ms preprocess, 32.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.3ms
# Speed: 1.8ms preprocess, 33.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 2.5ms preprocess, 32.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 1.8ms preprocess, 33.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 1.9ms preprocess, 33.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.8ms preprocess, 53.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.8ms
# Speed: 1.9ms preprocess, 33.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.5ms
# Speed: 2.4ms preprocess, 32.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.5ms
# Speed: 2.9ms preprocess, 32.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.3ms
# Speed: 2.7ms preprocess, 32.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.5ms
# Speed: 2.4ms preprocess, 32.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 3.0ms preprocess, 32.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.6ms
# Speed: 3.7ms preprocess, 37.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.7ms
# Speed: 3.0ms preprocess, 35.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.7ms
# Speed: 3.0ms preprocess, 33.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.7ms
# Speed: 2.7ms preprocess, 33.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.7ms
# Speed: 2.9ms preprocess, 32.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 32.8ms
# Speed: 2.2ms preprocess, 32.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 33.2ms
# Speed: 2.6ms preprocess, 33.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.9ms
# Speed: 2.1ms preprocess, 34.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 34.0ms
# Speed: 2.3ms preprocess, 34.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 33.7ms
# Speed: 2.6ms preprocess, 33.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 33.9ms
# Speed: 1.8ms preprocess, 33.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.8ms
# Speed: 3.0ms preprocess, 33.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Trash cans, 34.5ms
# Speed: 1.9ms preprocess, 34.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 3.1ms preprocess, 33.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.4ms
# Speed: 2.9ms preprocess, 34.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.1ms
# Speed: 3.3ms preprocess, 34.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 2.6ms preprocess, 33.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.0ms
# Speed: 1.9ms preprocess, 34.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 34.5ms
# Speed: 1.7ms preprocess, 34.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.7ms
# Speed: 2.3ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 34.4ms
# Speed: 2.8ms preprocess, 34.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 34.2ms
# Speed: 1.8ms preprocess, 34.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.0ms
# Speed: 2.4ms preprocess, 33.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 32.8ms
# Speed: 2.8ms preprocess, 32.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 39.0ms
# Speed: 5.9ms preprocess, 39.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 33.8ms
# Speed: 2.3ms preprocess, 33.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.1ms
# Speed: 2.8ms preprocess, 33.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.8ms
# Speed: 3.2ms preprocess, 33.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 34.3ms
# Speed: 2.0ms preprocess, 34.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 33.7ms
# Speed: 2.0ms preprocess, 33.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 35.0ms
# Speed: 5.3ms preprocess, 35.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 34.2ms
# Speed: 2.7ms preprocess, 34.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.8ms
# Speed: 2.1ms preprocess, 32.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 33.6ms
# Speed: 1.7ms preprocess, 33.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 1 Street lights, 34.0ms
# Speed: 1.7ms preprocess, 34.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 2 Street lightss, 33.3ms
# Speed: 2.6ms preprocess, 33.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 2 Street lightss, 33.0ms
# Speed: 1.8ms preprocess, 33.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 32.4ms
# Speed: 2.3ms preprocess, 32.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 32.5ms
# Speed: 1.9ms preprocess, 32.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 34.2ms
# Speed: 1.8ms preprocess, 34.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 2 Street lightss, 42.9ms
# Speed: 1.9ms preprocess, 42.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 2 Street lightss, 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 1 Outdoor advertising signs, 34.3ms
# Speed: 2.5ms preprocess, 34.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 1 Street lights, 33.5ms
# Speed: 2.7ms preprocess, 33.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 34.0ms
# Speed: 2.7ms preprocess, 34.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 34.3ms
# Speed: 1.7ms preprocess, 34.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 33.1ms
# Speed: 1.9ms preprocess, 33.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 33.3ms
# Speed: 2.6ms preprocess, 33.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Outdoor advertising signs, 1 Street lights, 34.0ms
# Speed: 1.7ms preprocess, 34.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 34.2ms
# Speed: 1.7ms preprocess, 34.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Street lights, 32.4ms
# Speed: 2.2ms preprocess, 32.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.9ms
# Speed: 2.6ms preprocess, 33.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.0ms
# Speed: 1.7ms preprocess, 34.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.0ms
# Speed: 2.1ms preprocess, 33.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 34.1ms
# Speed: 2.6ms preprocess, 34.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.5ms
# Speed: 1.8ms preprocess, 33.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.7ms
# Speed: 1.8ms preprocess, 33.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.4ms
# Speed: 1.9ms preprocess, 32.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.9ms
# Speed: 2.2ms preprocess, 31.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 34.0ms
# Speed: 1.9ms preprocess, 34.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.6ms
# Speed: 1.9ms preprocess, 33.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.6ms
# Speed: 1.7ms preprocess, 33.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.7ms
# Speed: 1.9ms preprocess, 33.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.2ms
# Speed: 2.5ms preprocess, 33.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 34.6ms
# Speed: 1.7ms preprocess, 34.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.5ms
# Speed: 2.2ms preprocess, 33.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.2ms
# Speed: 2.1ms preprocess, 33.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 34.2ms
# Speed: 1.7ms preprocess, 34.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.4ms
# Speed: 3.0ms preprocess, 33.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.6ms
# Speed: 1.7ms preprocess, 33.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.4ms
# Speed: 2.1ms preprocess, 32.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.6ms
# Speed: 1.7ms preprocess, 33.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.7ms
# Speed: 2.2ms preprocess, 33.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.1ms
# Speed: 2.2ms preprocess, 32.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.5ms
# Speed: 1.7ms preprocess, 33.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.7ms
# Speed: 2.2ms preprocess, 33.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.4ms
# Speed: 1.8ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.5ms
# Speed: 2.9ms preprocess, 32.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.0ms
# Speed: 2.2ms preprocess, 33.0ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.3ms
# Speed: 2.4ms preprocess, 32.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.9ms
# Speed: 2.3ms preprocess, 31.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.5ms
# Speed: 1.9ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 1.9ms preprocess, 33.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 2.3ms preprocess, 32.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.2ms
# Speed: 2.0ms preprocess, 32.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.2ms
# Speed: 2.0ms preprocess, 32.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 1.8ms preprocess, 33.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 1.8ms preprocess, 33.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 32.4ms
# Speed: 2.2ms preprocess, 32.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 33.3ms
# Speed: 2.2ms preprocess, 33.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 33.4ms
# Speed: 1.7ms preprocess, 33.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.0ms
# Speed: 2.1ms preprocess, 32.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 32.9ms
# Speed: 3.1ms preprocess, 32.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 33.0ms
# Speed: 1.8ms preprocess, 33.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 31.8ms
# Speed: 1.9ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Trash cans, 32.1ms
# Speed: 2.2ms preprocess, 32.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 31.7ms
# Speed: 2.2ms preprocess, 31.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Trash cans, 32.0ms
# Speed: 2.2ms preprocess, 32.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.2ms
# Speed: 2.9ms preprocess, 32.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.7ms
# Speed: 2.8ms preprocess, 32.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 33.0ms
# Speed: 2.7ms preprocess, 33.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.4ms
# Speed: 1.7ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.0ms
# Speed: 1.7ms preprocess, 32.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 31.8ms
# Speed: 2.0ms preprocess, 31.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.6ms
# Speed: 2.1ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 1 Trash cans, 32.4ms
# Speed: 1.7ms preprocess, 32.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.3ms
# Speed: 1.7ms preprocess, 32.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 31.7ms
# Speed: 2.4ms preprocess, 31.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 31.5ms
# Speed: 1.7ms preprocess, 31.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.9ms
# Speed: 2.7ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 31.7ms
# Speed: 1.7ms preprocess, 31.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 36.4ms
# Speed: 2.5ms preprocess, 36.4ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 31.8ms
# Speed: 2.3ms preprocess, 31.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 34.2ms
# Speed: 1.9ms preprocess, 34.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 33.2ms
# Speed: 3.1ms preprocess, 33.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 33.3ms
# Speed: 1.8ms preprocess, 33.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.7ms
# Speed: 1.8ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 31.5ms
# Speed: 1.7ms preprocess, 31.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 33.6ms
# Speed: 2.8ms preprocess, 33.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.3ms
# Speed: 1.8ms preprocess, 32.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 31.8ms
# Speed: 2.1ms preprocess, 31.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles parked on the sidewalks, 32.4ms
# Speed: 2.8ms preprocess, 32.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.5ms
# Speed: 2.1ms preprocess, 32.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.4ms
# Speed: 1.9ms preprocess, 32.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.3ms
# Speed: 1.8ms preprocess, 32.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.9ms
# Speed: 2.7ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.0ms
# Speed: 1.7ms preprocess, 32.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 33.3ms
# Speed: 1.8ms preprocess, 33.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles parked on the sidewalk, 31.5ms
# Speed: 1.7ms preprocess, 31.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Video: C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_annotated.mp4
# ✅ Audio: C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_audio.mp3
# ✅ Transcript: C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_audio.txt

# %%
import os
import time
import cv2
import torch
import numpy as np
from ultralytics import YOLOWorld
from gtts import gTTS
from openai import OpenAI
import re

# ─── CONFIG ──────────────────────────────────────────────────────────
VIDEO_IN    = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk.mp4"
VIDEO_OUT   = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_annotated.mp4"
AUDIO_DIR   = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\audio_clips"
FINAL_AUDIO = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_audio.mp3"
TRANSCRIPT  = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_audio.txt"

MODEL_WEIGHTS = "yolov8x-worldv2.pt"
FRAME_SKIP    = 5        # process every Nth frame
CONF_THRESH   = 0.6      # YOLO confidence threshold
OPENAI_KEY    = "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"  # your OpenAI key
# ──────────────────────────────────────────────────────────────────────

client = OpenAI(api_key=OPENAI_KEY)

# simple rate-limiter so we don't re-speak the same alert too often
spoken = {}
def speak_and_save(text: str, cooldown_s: float = 30.0):
    now = time.time()
    last = spoken.get(text, 0)
    if now - last < cooldown_s:
        return None
    spoken[text] = now
    os.makedirs(AUDIO_DIR, exist_ok=True)
    out_path = os.path.join(AUDIO_DIR, f"{int(now)}.mp3")
    gTTS(text).save(out_path)
    return out_path

def fetch_hazard_list():
    resp = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role":"system","content":"List 100 common hazards/obstacles on a city sidewalk, comma-separated."},
            {"role":"user","content":"Generate 100 common hazards/obstacles for a pedestrian walking in a city."}
        ],
        temperature=0.7,
        max_tokens=300
    )
    txt = resp.choices[0].message.content
    # split on commas or newlines, strip numbering
    items = re.split(r"[,\n]", txt)
    hazards = []
    for itm in items:
        h = itm.strip()
        if not h:
            continue
        h = re.sub(r"^\d+\.\s*", "", h)
        hazards.append(h)
    return hazards

def main():
    # 1) one-time fetch
    hazards = fetch_hazard_list()

    # 2) load model
    model = YOLOWorld(MODEL_WEIGHTS)
    model.conf = CONF_THRESH
    model.set_classes(hazards)

    # 3) setup I/O
    cap = cv2.VideoCapture(VIDEO_IN)
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(VIDEO_OUT, fourcc, fps/FRAME_SKIP, (w, h))

    left_x, right_x, middle_y = w*0.25, w*0.75, h*0.5
    audio_paths, alert_texts = [], []
    frame_id = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame_id += 1
        if frame_id % FRAME_SKIP != 0:
            continue

        device = "cuda" if torch.cuda.is_available() else "cpu"
        res = model.predict(frame, conf=CONF_THRESH, device=device)[0]
        preds = res.boxes.data.cpu().numpy()

        regions = {"ground": [], "left": [], "right": [], "front": []}

        # draw detections & classify
        for x1,y1,x2,y2,conf,cid in preds:
            name = res.names[int(cid)]
            cx, cy = (x1+x2)/2, (y1+y2)/2
            if cx < left_x:
                regions["left"].append(name)
            elif cx > right_x:
                regions["right"].append(name)
            elif cy < middle_y:
                regions["front"].append(name)
            else:
                regions["ground"].append(name)

            # red if on “ground” (close), green otherwise
            color = (0,0,255) if cy >= middle_y else (0,255,0)
            cv2.rectangle(frame, (int(x1),int(y1)), (int(x2),int(y2)), color, 2)
            cv2.putText(frame, f"{name} {conf:.2f}", (int(x1),int(y1)-6),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)

        # if any close (“ground”) obstacles, speak & record
        if regions["ground"]:
            txt = "Alert: ground obstacle – " + ", ".join(dict.fromkeys(regions["ground"]))
            alert_texts.append(txt)
            mp3 = speak_and_save(txt)
            if mp3:
                audio_paths.append(mp3)

        # draw H-split in blue
        for (x0,y0,x1,y1) in [
            (int(left_x),0,int(left_x),h),
            (int(right_x),0,int(right_x),h),
            (int(left_x),int(middle_y),int(right_x),int(middle_y))
        ]:
            cv2.line(frame, (x0,y0), (x1,y1), (255,0,0), 2)

        out.write(frame)

    cap.release()
    out.release()

    # ─── Merge all .mp3 clips by byte-concatenation ──────────────────────
    if audio_paths:
        with open(FINAL_AUDIO, "wb") as fw:
            for mp3 in sorted(audio_paths):
                with open(mp3, "rb") as fr:
                    fw.write(fr.read())
    else:
        print("⚠️  No audio clips generated; skipped audio merge.")

    # ─── Write full transcript ──────────────────────────────────────────
    with open(TRANSCRIPT, "w", encoding="utf-8") as tf:
        tf.write("\n".join(alert_texts) or "No alerts detected.")

    print("✅ Annotated video:", VIDEO_OUT)
    print("✅ Merged audio  :", FINAL_AUDIO)
    print("✅ Transcript   :", TRANSCRIPT)

if __name__ == "__main__":
    main()
# Out:
# 0: 384x640 (no detections), 36.7ms
# Speed: 3.0ms preprocess, 36.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 1.7ms preprocess, 33.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.9ms
# Speed: 1.8ms preprocess, 32.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.9ms
# Speed: 1.9ms preprocess, 31.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.8ms
# Speed: 2.2ms preprocess, 33.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.1ms
# Speed: 2.7ms preprocess, 34.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.5ms
# Speed: 2.1ms preprocess, 32.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 2.1ms preprocess, 32.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.3ms
# Speed: 2.2ms preprocess, 32.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 2.3ms preprocess, 32.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.9ms
# Speed: 2.2ms preprocess, 31.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.9ms
# Speed: 2.7ms preprocess, 32.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.7ms
# Speed: 2.4ms preprocess, 33.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 36.5ms
# Speed: 2.8ms preprocess, 36.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.2ms
# Speed: 2.3ms preprocess, 32.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.3ms
# Speed: 2.3ms preprocess, 32.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 2.3ms preprocess, 32.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 3.0ms preprocess, 33.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 3.0ms preprocess, 35.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.9ms
# Speed: 2.9ms preprocess, 33.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.3ms
# Speed: 2.5ms preprocess, 34.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 34.0ms
# Speed: 2.9ms preprocess, 34.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.0ms
# Speed: 1.8ms preprocess, 33.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 32.9ms
# Speed: 2.1ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 32.5ms
# Speed: 2.3ms preprocess, 32.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.2ms
# Speed: 2.1ms preprocess, 32.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 30.7ms
# Speed: 2.3ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.0ms
# Speed: 1.7ms preprocess, 32.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.9ms
# Speed: 1.8ms preprocess, 31.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.0ms
# Speed: 1.9ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.9ms
# Speed: 2.2ms preprocess, 30.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.5ms
# Speed: 1.7ms preprocess, 31.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 3.2ms preprocess, 32.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.8ms
# Speed: 1.8ms preprocess, 30.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.5ms
# Speed: 1.7ms preprocess, 31.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Bicycles chained to poless, 37.7ms
# Speed: 3.4ms preprocess, 37.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 33.0ms
# Speed: 2.9ms preprocess, 33.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 33.0ms
# Speed: 3.4ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Bicycles chained to poless, 33.1ms
# Speed: 2.9ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.1ms
# Speed: 1.8ms preprocess, 31.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.9ms
# Speed: 1.9ms preprocess, 31.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.1ms
# Speed: 1.8ms preprocess, 31.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.9ms
# Speed: 1.9ms preprocess, 31.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.3ms
# Speed: 1.7ms preprocess, 31.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.2ms
# Speed: 2.0ms preprocess, 31.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fire hydrants, 31.8ms
# Speed: 1.9ms preprocess, 31.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.4ms
# Speed: 2.0ms preprocess, 31.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Trash cans, 3 Bicycles chained to poless, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.5ms
# Speed: 2.2ms preprocess, 31.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.2ms
# Speed: 1.7ms preprocess, 31.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.4ms
# Speed: 1.7ms preprocess, 32.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 35.2ms
# Speed: 3.1ms preprocess, 35.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 37.3ms
# Speed: 3.3ms preprocess, 37.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.9ms
# Speed: 2.8ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.7ms
# Speed: 1.7ms preprocess, 31.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.1ms
# Speed: 2.0ms preprocess, 32.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 42.7ms
# Speed: 3.1ms preprocess, 42.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.9ms
# Speed: 3.7ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 32.7ms
# Speed: 1.8ms preprocess, 32.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 31.8ms
# Speed: 1.8ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.4ms
# Speed: 2.1ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 31.3ms
# Speed: 1.7ms preprocess, 31.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.8ms
# Speed: 1.7ms preprocess, 31.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.4ms
# Speed: 1.7ms preprocess, 31.4ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.4ms
# Speed: 1.7ms preprocess, 31.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.1ms
# Speed: 3.0ms preprocess, 32.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.8ms
# Speed: 1.7ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.7ms
# Speed: 2.3ms preprocess, 31.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.4ms
# Speed: 1.8ms preprocess, 31.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.6ms
# Speed: 2.0ms preprocess, 31.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.5ms
# Speed: 1.7ms preprocess, 31.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.7ms
# Speed: 1.8ms preprocess, 31.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.6ms
# Speed: 1.7ms preprocess, 31.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.6ms
# Speed: 1.8ms preprocess, 31.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.4ms
# Speed: 1.9ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 30.9ms
# Speed: 1.8ms preprocess, 30.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 36.5ms
# Speed: 1.9ms preprocess, 36.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 30.8ms
# Speed: 2.6ms preprocess, 30.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.4ms
# Speed: 2.3ms preprocess, 32.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.1ms
# Speed: 2.1ms preprocess, 32.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.4ms
# Speed: 1.9ms preprocess, 33.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 33.3ms
# Speed: 1.9ms preprocess, 33.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 33.3ms
# Speed: 2.7ms preprocess, 33.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.1ms
# Speed: 2.1ms preprocess, 32.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.4ms
# Speed: 1.7ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.9ms
# Speed: 2.9ms preprocess, 32.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.9ms
# Speed: 2.7ms preprocess, 32.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 3.3ms preprocess, 33.4ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.5ms
# Speed: 1.9ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.9ms
# Speed: 2.8ms preprocess, 32.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.4ms
# Speed: 2.4ms preprocess, 32.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.4ms
# Speed: 3.5ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 33.5ms
# Speed: 1.9ms preprocess, 33.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 32.5ms
# Speed: 2.6ms preprocess, 32.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.8ms
# Speed: 2.5ms preprocess, 32.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 32.5ms
# Speed: 3.4ms preprocess, 32.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 32.2ms
# Speed: 2.3ms preprocess, 32.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 32.9ms
# Speed: 1.8ms preprocess, 32.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 31.7ms
# Speed: 2.2ms preprocess, 31.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 31.8ms
# Speed: 2.3ms preprocess, 31.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.4ms
# Speed: 1.7ms preprocess, 32.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.6ms
# Speed: 2.7ms preprocess, 31.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 32.4ms
# Speed: 2.2ms preprocess, 32.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.5ms
# Speed: 1.7ms preprocess, 31.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 32.4ms
# Speed: 1.9ms preprocess, 32.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 2 Street lightss, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 2 Street lightss, 31.4ms
# Speed: 1.9ms preprocess, 31.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.9ms
# Speed: 1.8ms preprocess, 32.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 32.2ms
# Speed: 3.0ms preprocess, 32.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 1 Street lights, 32.3ms
# Speed: 2.5ms preprocess, 32.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 1 Street lights, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 33.1ms
# Speed: 2.1ms preprocess, 33.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 1 Street lights, 33.6ms
# Speed: 2.2ms preprocess, 33.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.6ms
# Speed: 2.3ms preprocess, 33.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.6ms
# Speed: 1.9ms preprocess, 31.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 34.7ms
# Speed: 1.7ms preprocess, 34.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.5ms
# Speed: 1.9ms preprocess, 32.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.2ms
# Speed: 2.5ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 33.3ms
# Speed: 2.8ms preprocess, 33.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 31.7ms
# Speed: 1.7ms preprocess, 31.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 31.8ms
# Speed: 2.9ms preprocess, 31.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.5ms
# Speed: 1.7ms preprocess, 31.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.6ms
# Speed: 1.7ms preprocess, 31.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.7ms
# Speed: 1.7ms preprocess, 31.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 31.4ms
# Speed: 1.7ms preprocess, 31.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.7ms
# Speed: 2.7ms preprocess, 32.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.7ms
# Speed: 1.8ms preprocess, 31.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.9ms
# Speed: 1.9ms preprocess, 31.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.3ms
# Speed: 1.8ms preprocess, 32.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.3ms
# Speed: 2.1ms preprocess, 33.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.7ms
# Speed: 1.7ms preprocess, 31.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.5ms
# Speed: 2.7ms preprocess, 32.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 1.8ms preprocess, 33.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.6ms
# Speed: 2.3ms preprocess, 31.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.1ms
# Speed: 2.3ms preprocess, 32.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.0ms
# Speed: 2.7ms preprocess, 33.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.9ms
# Speed: 1.9ms preprocess, 31.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.3ms
# Speed: 1.7ms preprocess, 32.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.9ms
# Speed: 1.9ms preprocess, 31.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.3ms
# Speed: 1.7ms preprocess, 32.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 2.1ms preprocess, 33.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.0ms
# Speed: 5.3ms preprocess, 34.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.5ms
# Speed: 6.4ms preprocess, 33.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.1ms
# Speed: 2.0ms preprocess, 32.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.7ms
# Speed: 2.0ms preprocess, 31.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.8ms
# Speed: 1.8ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.7ms
# Speed: 2.4ms preprocess, 31.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.4ms
# Speed: 1.8ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.9ms
# Speed: 2.1ms preprocess, 31.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.6ms
# Speed: 1.7ms preprocess, 33.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.7ms
# Speed: 1.8ms preprocess, 31.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.6ms
# Speed: 1.7ms preprocess, 31.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.7ms
# Speed: 1.8ms preprocess, 32.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.2ms
# Speed: 1.8ms preprocess, 31.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.8ms
# Speed: 1.8ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.8ms
# Speed: 1.8ms preprocess, 31.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.8ms
# Speed: 2.1ms preprocess, 31.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.4ms
# Speed: 1.8ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.4ms
# Speed: 3.5ms preprocess, 32.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 33.0ms
# Speed: 1.8ms preprocess, 33.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.7ms
# Speed: 1.8ms preprocess, 31.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus shelters, 1 Street lights, 32.3ms
# Speed: 1.7ms preprocess, 32.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus shelters, 1 Street lights, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus shelters, 1 Street lights, 33.9ms
# Speed: 3.2ms preprocess, 33.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus shelters, 1 Street lights, 32.0ms
# Speed: 1.9ms preprocess, 32.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.2ms
# Speed: 2.2ms preprocess, 32.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.9ms
# Speed: 1.8ms preprocess, 32.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.8ms
# Speed: 2.1ms preprocess, 31.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.0ms
# Speed: 2.2ms preprocess, 32.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.4ms
# Speed: 2.6ms preprocess, 32.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 1 Street lights, 32.0ms
# Speed: 2.1ms preprocess, 32.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic cones, 1 Street lights, 32.2ms
# Speed: 2.0ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.7ms
# Speed: 2.7ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 32.3ms
# Speed: 1.8ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Street lights, 32.3ms
# Speed: 1.7ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus shelters, 1 Street lights, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.6ms
# Speed: 1.7ms preprocess, 31.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 31.9ms
# Speed: 1.9ms preprocess, 31.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Street lights, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.9ms
# Speed: 2.8ms preprocess, 32.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.6ms
# Speed: 2.0ms preprocess, 31.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.9ms
# Speed: 1.8ms preprocess, 32.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 3.0ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.4ms
# Speed: 1.9ms preprocess, 31.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 2.2ms preprocess, 32.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.3ms
# Speed: 1.9ms preprocess, 33.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus shelters, 31.8ms
# Speed: 1.7ms preprocess, 31.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.7ms
# Speed: 2.2ms preprocess, 34.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 2.6ms preprocess, 33.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.6ms
# Speed: 1.7ms preprocess, 31.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 2.7ms preprocess, 33.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.7ms
# Speed: 2.8ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.3ms
# Speed: 2.5ms preprocess, 32.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.4ms
# Speed: 1.7ms preprocess, 32.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 1.9ms preprocess, 32.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 1.7ms preprocess, 32.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 2.2ms preprocess, 32.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.8ms
# Speed: 2.3ms preprocess, 31.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 2.5ms preprocess, 32.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.4ms
# Speed: 1.8ms preprocess, 31.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.3ms
# Speed: 2.2ms preprocess, 31.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.1ms
# Speed: 2.8ms preprocess, 32.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 3.3ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.8ms
# Speed: 2.4ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.6ms
# Speed: 1.7ms preprocess, 31.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 31.7ms
# Speed: 1.7ms preprocess, 31.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Trash cans, 2 Bicycles chained to poless, 31.3ms
# Speed: 1.7ms preprocess, 31.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.6ms
# Speed: 1.7ms preprocess, 31.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.6ms
# Speed: 1.7ms preprocess, 31.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.5ms
# Speed: 1.8ms preprocess, 31.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.3ms
# Speed: 2.1ms preprocess, 32.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.5ms
# Speed: 2.6ms preprocess, 33.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 2.1ms preprocess, 33.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Trash cans, 1 Bicycles chained to poles, 33.6ms
# Speed: 2.2ms preprocess, 33.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Trash cans, 32.2ms
# Speed: 2.3ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.0ms
# Speed: 2.7ms preprocess, 33.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.4ms
# Speed: 2.3ms preprocess, 32.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Trash cans, 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.6ms
# Speed: 2.6ms preprocess, 33.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.4ms
# Speed: 2.2ms preprocess, 32.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 2.5ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.4ms
# Speed: 3.3ms preprocess, 32.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 1.8ms preprocess, 33.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 2.7ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.5ms
# Speed: 2.4ms preprocess, 32.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 1.8ms preprocess, 33.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.7ms
# Speed: 1.7ms preprocess, 31.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.8ms
# Speed: 1.9ms preprocess, 31.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.8ms
# Speed: 2.4ms preprocess, 31.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Trash cans, 1 Bicycles chained to poles, 32.3ms
# Speed: 1.7ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.6ms
# Speed: 2.2ms preprocess, 31.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.3ms
# Speed: 1.8ms preprocess, 32.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.2ms
# Speed: 2.9ms preprocess, 32.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 33.0ms
# Speed: 1.8ms preprocess, 33.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.2ms
# Speed: 2.3ms preprocess, 32.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Bus shelters, 32.2ms
# Speed: 2.1ms preprocess, 32.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 32.6ms
# Speed: 2.1ms preprocess, 32.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.0ms
# Speed: 2.8ms preprocess, 33.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.4ms
# Speed: 2.2ms preprocess, 32.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 34.1ms
# Speed: 1.9ms preprocess, 34.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.8ms
# Speed: 2.0ms preprocess, 32.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.7ms
# Speed: 1.7ms preprocess, 33.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.1ms
# Speed: 1.9ms preprocess, 32.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.1ms
# Speed: 1.9ms preprocess, 32.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.4ms
# Speed: 3.1ms preprocess, 32.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.0ms
# Speed: 2.2ms preprocess, 32.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.2ms
# Speed: 1.8ms preprocess, 33.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.4ms
# Speed: 2.6ms preprocess, 31.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.8ms
# Speed: 2.4ms preprocess, 31.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Trash cans, 1 Bicycles chained to poles, 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.5ms
# Speed: 7.8ms preprocess, 36.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Trash cans, 1 Bicycles chained to poles, 32.4ms
# Speed: 2.2ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Trash cans, 1 Bicycles chained to poles, 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.4ms
# Speed: 2.3ms preprocess, 32.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.4ms
# Speed: 2.8ms preprocess, 32.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Bicycles chained to poless, 32.1ms
# Speed: 2.1ms preprocess, 32.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bicycles chained to poless, 33.3ms
# Speed: 1.8ms preprocess, 33.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.7ms
# Speed: 1.7ms preprocess, 31.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.8ms
# Speed: 1.8ms preprocess, 31.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.0ms
# Speed: 1.8ms preprocess, 33.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 1.7ms preprocess, 32.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.5ms
# Speed: 1.8ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.5ms
# Speed: 2.3ms preprocess, 32.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.1ms
# Speed: 2.0ms preprocess, 32.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.6ms
# Speed: 2.3ms preprocess, 31.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Utility boxes, 32.9ms
# Speed: 2.2ms preprocess, 32.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.9ms
# Speed: 2.8ms preprocess, 32.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 31.8ms
# Speed: 2.0ms preprocess, 31.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 1.7ms preprocess, 33.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.8ms
# Speed: 2.1ms preprocess, 32.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.2ms
# Speed: 2.2ms preprocess, 32.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 1 Utility boxes, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.3ms
# Speed: 1.7ms preprocess, 32.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 32.5ms
# Speed: 2.1ms preprocess, 32.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bicycles chained to poles, 33.2ms
# Speed: 2.1ms preprocess, 33.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Annotated video: C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_annotated.mp4
# ✅ Merged audio  : C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_audio.mp3
# ✅ Transcript   : C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_audio.txt

# %%
print("CUDA Available:", torch.cuda.is_available())
print("Device Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# CUDA Available: True
# Device Name: NVIDIA GeForce GTX 1080

# %%
client = OpenAI(api_key="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")
tts_engine = pyttsx3.init()
tts_engine.setProperty('rate', 150)  # Adjust speaking speed
spoken_messages = {}
message_timeout = 30 # seconds
fallback_counter = 0
fallback_threshold = 3 # After x amount, delcare uncertain
saved_audio_paths = []

# %%
def speak_and_save(text, audio_output_dir="audio_clips"):
    now = time.time()
    if text:
        last = spoken_messages.get(text, 0)
        if now - last > message_timeout:
            spoken_messages[text] = now
            os.makedirs(audio_output_dir, exist_ok=True)
            path = os.path.join(audio_output_dir, f"{int(now)}.mp3")
            gTTS(text).save(path)
            return path
    return None

# %%
def initialize_model_and_video(video_file, output_video_file, weight_file, walking_hazards, frame_skip):
    model = YOLOWorld(weight_file)
    model.set_classes(walking_hazards)

    cap = cv2.VideoCapture(video_file)
    if not cap.isOpened():
        raise IOError("Cannot open video")

    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_file, fourcc, fps // frame_skip, (width, height))

    return model, cap, out

# %%
def detect_objects_in_frame(model, frame, confidence_threshold=0.6):
    """Run YOLO-World, filter by threshold, then mark low-confidence anomalies."""
    results = model.predict(frame)
    preds   = results[0].boxes.data.cpu().numpy()
    objs    = []

    # collect detections above threshold
    for x1,y1,x2,y2,score,cid in preds:
        if score >= confidence_threshold:
            objs.append({
                'name': model.names[int(cid)],
                'box': (int(x1),int(y1),int(x2),int(y2)),
                'score': float(score),
                'anomaly': False
            })

    # statistical anomaly: score < (mean - std)
    if len(objs) > 1:
        scores = np.array([o['score'] for o in objs])
        m, s    = scores.mean(), scores.std()
        threshold = m - s
        for o in objs:
            if o['score'] < threshold:
                o['anomaly'] = True
    return objs

# %%
def summarize_with_llm(objects, mode="description"):
    """Summarize detected objects using OpenAI's LLM."""
    if not objects:
        return None

    objects_summary = {}
    for obj in objects:
        name = obj['name']
        objects_summary[name] = objects_summary.get(name, 0) + 1


    text_summary = ", ".join([f"{count} {obj}(s)" for obj, count in objects_summary.items()])

    if mode == "description":
        prompt = f"Describe the following environment in natural language: {text_summary}"
    elif mode == "warning":
        prompt = f"Based on the following objects, generate a short warning message if there is any obstacle: {text_summary}"

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are an assistant that helps with real-time navigation for visually impaired users."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.5,
        max_tokens=100
    )

    return response.choices[0].message.content.strip()

# %%
def process_video(model, cap, out, frame_skip, confidence_threshold, describe_interval):
    global fallback_counter
    frame_id = 0
    last_desc = time.time()
    seen_set  = set()
    warn_last = ""

    # initial description
    ret, frame = cap.read()
    if ret:
        objs = detect_objects_in_frame(model, frame, confidence_threshold)
        if objs:
            desc = summarize_with_llm(objs,'description')
            print(f"📄 {desc}")
            p = speak_and_save(desc)
            if p: saved_audio_paths.append(p)
        last_desc = time.time()
    cap.set(cv2.CAP_PROP_POS_FRAMES,0)

    while True:
        ret, frame = cap.read()
        if not ret: break
        frame_id += 1
        if frame_id % frame_skip: continue

        objs = detect_objects_in_frame(model, frame, confidence_threshold)
        if not objs:
            fallback_counter +=1
            if fallback_counter >= fallback_threshold:
                p = speak_and_save("Low confidence, proceed with caution.")
                if p: saved_audio_paths.append(p)
                fallback_counter=0
            continue
        fallback_counter=0

        names = set([o['name'] for o in objs])
        # draw each box
        for o in objs:
            x1,y1,x2,y2 = o['box']
            color = (0,0,255) if o['anomaly'] else (0,255,0)
            cv2.rectangle(frame,(x1,y1),(x2,y2),color,2)
            label = f"{o['name']} {o['score']:.2f}"
            if o['anomaly']: label += " (!)"
            cv2.putText(frame,label,(x1,y1-10),cv2.FONT_HERSHEY_SIMPLEX,0.6,color,2)

        # periodic description
        if time.time() - last_desc > describe_interval:
            desc = summarize_with_llm(objs,'description')
            print(f"📄 {desc}")
            p = speak_and_save(desc)
            if p: saved_audio_paths.append(p)
            last_desc = time.time()

        # warnings on set change
        if names!=seen_set:
            warn = summarize_with_llm(objs,'warning')
            if warn and warn!=warn_last:
                print(f"⚠️ {warn}")
                p = speak_and_save(warn)
                if p: saved_audio_paths.append(p)
                warn_last = warn
            seen_set = names

        out.write(frame)
    cap.release()
    out.release()
    print("✅ Done processing video.")

# %%
if __name__ == "__main__":
    # File paths
    video_file = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk.mp4"
    output_video_file = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_annotated.mp4"
    audio_file = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_audio.mp3"
    weight_file = 'yolov8x-worldv2.pt'
    frame_skip = 5
    confidence_threshold = 0.6
    describe_interval = 60  # seconds between descriptions

    walking_hazards = [
        'person', 'bicycle', 'car', 'motorcycle', 'bus', 'truck', 'traffic light', 'stop sign', 'red light', 'green light'
    ]

    model, cap, out = initialize_model_and_video(video_file, output_video_file, weight_file, walking_hazards, frame_skip)
    process_video(model, cap, out, frame_skip, confidence_threshold, describe_interval)
    add_audio_to_video(output_video_file, "audio_clips", audio_file)

    print("Video and audio saved.")

# %%
import os
import cv2
import torch
import numpy as np
from gtts import gTTS
from ultralytics import YOLOWorld

def main():
    # ─── CONFIG ────────────────────────────────────────────────────────────────
    VIDEO_IN      = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk.mp4"
    VIDEO_OUT     = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_annotated.mp4"
    FINAL_AUDIO   = r"C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_audio.mp3"
    MODEL_WEIGHTS = "yolov8x-worldv2.pt"
    FPS           = 10               # desired write‐out FPS
    CONF_THRESH   = 0.5              # detection confidence threshold
    MEMORY_TTL    = 30               # frames between repeated warnings per object
    # ────────────────────────────────────────────────────────────────────────────

    # load model
    model = YOLOWorld(MODEL_WEIGHTS)
    model.conf = CONF_THRESH

    # open I/O
    cap = cv2.VideoCapture(VIDEO_IN)
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out    = cv2.VideoWriter(VIDEO_OUT, fourcc, FPS, (w, h))

    # memory so we only re-warn each object every MEMORY_TTL frames
    last_warn = {}   # tracker_id -> last_frame_warned
    warnings   = []  # collect all warning texts

    frame_id = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame_id += 1

        # run detection
        results = model(frame)[0]
        boxes   = results.boxes.xyxy.cpu().numpy()
        scores  = results.boxes.conf.cpu().numpy()
        tids    = getattr(results.boxes, "ids",
                           np.arange(len(boxes)))
        classes = results.boxes.cls.cpu().numpy().astype(int)

        # annotate & warnings
        for (x1, y1, x2, y2), conf, tid, cls in zip(boxes, scores, tids, classes):
            if conf < CONF_THRESH:
                continue
            # draw bbox
            cv2.rectangle(frame,
                          (int(x1), int(y1)),
                          (int(x2), int(y2)),
                          (0, 255, 0), 2)
            label = f"{model.names[cls]} {conf:0.2f}"
            cv2.putText(frame, label,
                        (int(x1), int(y1) - 5),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        0.5, (0, 255, 0), 1)

            # ground region warning
            cy = (y1 + y2) / 2
            if cy > h * 0.5:
                last = last_warn.get(tid, -MEMORY_TTL)
                if frame_id - last >= MEMORY_TTL:
                    txt = f"Warning: {model.names[cls]} ahead."
                    warnings.append(txt)
                    last_warn[tid] = frame_id

        out.write(frame)

    cap.release()
    out.release()
    print("✅ Annotated video saved to", VIDEO_OUT)

    # ─── single TTS pass over all warnings ────────────────────────────────────
    if warnings:
        full_text = " ".join(warnings)
        tts = gTTS(full_text)
        tts.save(FINAL_AUDIO)
        print("✅ Final audio saved to", FINAL_AUDIO)
    else:
        print("⚠️  No warnings were generated, so no audio file created.")

if __name__ == "__main__":
    main()
# Out:
# 0: 384x640 2 persons, 2 traffic lights, 46.2ms
# Speed: 2.8ms preprocess, 46.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 36.7ms
# Speed: 3.0ms preprocess, 36.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 35.9ms
# Speed: 3.2ms preprocess, 35.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 33.8ms
# Speed: 2.4ms preprocess, 33.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 33.3ms
# Speed: 2.4ms preprocess, 33.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 traffic lights, 32.9ms
# Speed: 2.2ms preprocess, 32.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 1 stop sign, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 traffic lights, 33.6ms
# Speed: 3.0ms preprocess, 33.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 1 stop sign, 32.7ms
# Speed: 2.2ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 traffic light, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 traffic light, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 traffic light, 32.2ms
# Speed: 2.0ms preprocess, 32.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 1 stop sign, 32.6ms
# Speed: 3.2ms preprocess, 32.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 1 stop sign, 32.3ms
# Speed: 2.6ms preprocess, 32.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 32.8ms
# Speed: 2.7ms preprocess, 32.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 32.2ms
# Speed: 2.7ms preprocess, 32.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 32.4ms
# Speed: 3.2ms preprocess, 32.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 traffic light, 32.9ms
# Speed: 2.5ms preprocess, 32.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 traffic light, 33.5ms
# Speed: 2.2ms preprocess, 33.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 33.6ms
# Speed: 2.1ms preprocess, 33.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 32.4ms
# Speed: 2.3ms preprocess, 32.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 31.7ms
# Speed: 2.6ms preprocess, 31.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 traffic lights, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 32.8ms
# Speed: 2.6ms preprocess, 32.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 33.1ms
# Speed: 3.0ms preprocess, 33.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 32.4ms
# Speed: 2.6ms preprocess, 32.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 62.0ms
# Speed: 3.2ms preprocess, 62.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 32.5ms
# Speed: 2.1ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 32.7ms
# Speed: 2.9ms preprocess, 32.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 31.8ms
# Speed: 2.5ms preprocess, 31.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 33.7ms
# Speed: 2.9ms preprocess, 33.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 33.4ms
# Speed: 1.8ms preprocess, 33.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 33.6ms
# Speed: 2.3ms preprocess, 33.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 33.1ms
# Speed: 1.9ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 32.9ms
# Speed: 2.2ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 32.0ms
# Speed: 2.8ms preprocess, 32.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 33.4ms
# Speed: 2.7ms preprocess, 33.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 31.6ms
# Speed: 2.6ms preprocess, 31.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 32.7ms
# Speed: 2.2ms preprocess, 32.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 31.9ms
# Speed: 2.0ms preprocess, 31.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 33.1ms
# Speed: 3.3ms preprocess, 33.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 32.7ms
# Speed: 2.0ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 33.6ms
# Speed: 1.8ms preprocess, 33.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 32.2ms
# Speed: 2.8ms preprocess, 32.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 33.3ms
# Speed: 1.8ms preprocess, 33.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 33.4ms
# Speed: 1.9ms preprocess, 33.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 32.3ms
# Speed: 2.6ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 32.4ms
# Speed: 2.6ms preprocess, 32.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 32.5ms
# Speed: 2.5ms preprocess, 32.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 33.2ms
# Speed: 2.1ms preprocess, 33.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 traffic lights, 33.3ms
# Speed: 2.2ms preprocess, 33.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 traffic lights, 34.0ms
# Speed: 1.7ms preprocess, 34.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 traffic lights, 32.4ms
# Speed: 2.6ms preprocess, 32.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 33.1ms
# Speed: 2.3ms preprocess, 33.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 traffic light, 1 stop sign, 33.4ms
# Speed: 1.9ms preprocess, 33.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 traffic lights, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 traffic lights, 32.2ms
# Speed: 2.1ms preprocess, 32.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 traffic lights, 32.6ms
# Speed: 2.1ms preprocess, 32.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 33.4ms
# Speed: 2.1ms preprocess, 33.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 traffic lights, 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 traffic lights, 32.0ms
# Speed: 2.9ms preprocess, 32.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 traffic lights, 32.4ms
# Speed: 2.6ms preprocess, 32.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 traffic lights, 32.4ms
# Speed: 2.1ms preprocess, 32.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 33.0ms
# Speed: 2.6ms preprocess, 33.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 traffic lights, 32.4ms
# Speed: 2.6ms preprocess, 32.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 traffic lights, 33.4ms
# Speed: 1.8ms preprocess, 33.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 traffic lights, 33.3ms
# Speed: 2.0ms preprocess, 33.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 traffic lights, 31.4ms
# Speed: 2.0ms preprocess, 31.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 traffic lights, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 2 traffic lights, 33.1ms
# Speed: 2.7ms preprocess, 33.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 2 traffic lights, 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 2 traffic lights, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 2 traffic lights, 32.2ms
# Speed: 2.7ms preprocess, 32.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 3 traffic lights, 33.0ms
# Speed: 2.9ms preprocess, 33.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 2 traffic lights, 32.7ms
# Speed: 2.9ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 traffic light, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 traffic light, 32.9ms
# Speed: 2.1ms preprocess, 32.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 2 traffic lights, 31.3ms
# Speed: 1.9ms preprocess, 31.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 2 traffic lights, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 1 teddy bear, 32.6ms
# Speed: 2.6ms preprocess, 32.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 1 teddy bear, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 1 teddy bear, 33.5ms
# Speed: 2.9ms preprocess, 33.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 2 traffic lights, 32.0ms
# Speed: 2.3ms preprocess, 32.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 2 traffic lights, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 1 bottle, 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 1 bottle, 33.6ms
# Speed: 2.3ms preprocess, 33.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 1 bottle, 32.3ms
# Speed: 2.5ms preprocess, 32.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 33.4ms
# Speed: 1.8ms preprocess, 33.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 2 traffic lights, 32.5ms
# Speed: 3.0ms preprocess, 32.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 2 traffic lights, 32.4ms
# Speed: 2.2ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 2 traffic lights, 32.2ms
# Speed: 2.5ms preprocess, 32.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 32.5ms
# Speed: 2.0ms preprocess, 32.5ms inference, 29.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 1 bird, 32.9ms
# Speed: 1.8ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 1 bird, 32.0ms
# Speed: 2.1ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 1 bird, 32.8ms
# Speed: 2.5ms preprocess, 32.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 1 umbrella, 32.6ms
# Speed: 2.5ms preprocess, 32.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 1 umbrella, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 2 traffic lights, 32.7ms
# Speed: 3.2ms preprocess, 32.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 2 traffic lights, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 2 traffic lights, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 2 traffic lights, 33.8ms
# Speed: 1.9ms preprocess, 33.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 2 traffic lights, 33.2ms
# Speed: 2.9ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 cars, 1 traffic light, 1 stop sign, 32.4ms
# Speed: 2.4ms preprocess, 32.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 cars, 1 traffic light, 1 stop sign, 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 cars, 1 traffic light, 1 stop sign, 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 traffic light, 1 fire hydrant, 1 stop sign, 32.4ms
# Speed: 2.0ms preprocess, 32.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 traffic light, 1 fire hydrant, 1 stop sign, 33.1ms
# Speed: 1.9ms preprocess, 33.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 traffic light, 1 stop sign, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 traffic light, 1 stop sign, 32.8ms
# Speed: 2.6ms preprocess, 32.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 traffic light, 1 stop sign, 33.1ms
# Speed: 2.2ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 2 traffic lights, 1 teddy bear, 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 2 traffic lights, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 traffic light, 1 stop sign, 1 handbag, 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 traffic light, 1 stop sign, 1 handbag, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 traffic light, 1 stop sign, 1 handbag, 32.7ms
# Speed: 3.1ms preprocess, 32.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 cars, 2 traffic lights, 32.7ms
# Speed: 2.7ms preprocess, 32.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 cars, 2 traffic lights, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.4ms
# Speed: 2.9ms preprocess, 33.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.1ms
# Speed: 3.0ms preprocess, 33.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.3ms
# Speed: 2.4ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 1 motorcycle, 2 traffic lights, 32.4ms
# Speed: 2.6ms preprocess, 32.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 1 motorcycle, 2 traffic lights, 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.7ms
# Speed: 2.2ms preprocess, 32.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 32.6ms
# Speed: 2.3ms preprocess, 32.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 33.1ms
# Speed: 1.9ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 1 car, 1 motorcycle, 2 traffic lights, 34.0ms
# Speed: 1.8ms preprocess, 34.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 1 car, 1 motorcycle, 2 traffic lights, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 1 car, 2 traffic lights, 34.0ms
# Speed: 1.9ms preprocess, 34.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 1 car, 2 traffic lights, 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 1 car, 2 traffic lights, 33.2ms
# Speed: 2.8ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 traffic light, 1 stop sign, 34.1ms
# Speed: 1.9ms preprocess, 34.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 traffic light, 1 stop sign, 32.4ms
# Speed: 2.0ms preprocess, 32.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.4ms
# Speed: 1.8ms preprocess, 33.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 31.9ms
# Speed: 2.8ms preprocess, 31.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 1 car, 3 traffic lights, 32.8ms
# Speed: 2.6ms preprocess, 32.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 1 car, 3 traffic lights, 33.4ms
# Speed: 1.9ms preprocess, 33.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 32.3ms
# Speed: 2.2ms preprocess, 32.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 32.2ms
# Speed: 2.6ms preprocess, 32.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 1 car, 2 traffic lights, 31.9ms
# Speed: 2.5ms preprocess, 31.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 1 car, 2 traffic lights, 33.6ms
# Speed: 1.9ms preprocess, 33.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 33.0ms
# Speed: 2.8ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 33.2ms
# Speed: 2.6ms preprocess, 33.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 32.5ms
# Speed: 2.7ms preprocess, 32.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 1 car, 2 traffic lights, 32.3ms
# Speed: 2.4ms preprocess, 32.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 1 car, 2 traffic lights, 32.5ms
# Speed: 3.0ms preprocess, 32.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 bicycles, 1 car, 2 traffic lights, 1 stop sign, 33.4ms
# Speed: 2.7ms preprocess, 33.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 bicycles, 1 car, 2 traffic lights, 1 stop sign, 32.6ms
# Speed: 2.2ms preprocess, 32.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 bicycles, 1 car, 2 traffic lights, 1 stop sign, 32.4ms
# Speed: 3.0ms preprocess, 32.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 bicycles, 1 car, 3 traffic lights, 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 bicycles, 1 car, 3 traffic lights, 31.9ms
# Speed: 2.2ms preprocess, 31.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 1 stop sign, 32.3ms
# Speed: 2.3ms preprocess, 32.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 1 stop sign, 33.6ms
# Speed: 2.4ms preprocess, 33.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 1 stop sign, 33.3ms
# Speed: 2.1ms preprocess, 33.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 32.5ms
# Speed: 2.8ms preprocess, 32.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 33.3ms
# Speed: 2.4ms preprocess, 33.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 31.8ms
# Speed: 2.4ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 33.3ms
# Speed: 1.9ms preprocess, 33.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 34.0ms
# Speed: 1.9ms preprocess, 34.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 42.0ms
# Speed: 2.9ms preprocess, 42.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 32.7ms
# Speed: 2.3ms preprocess, 32.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 31.7ms
# Speed: 2.7ms preprocess, 31.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 34.2ms
# Speed: 1.8ms preprocess, 34.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bicycles, 1 car, 2 traffic lights, 33.5ms
# Speed: 1.9ms preprocess, 33.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bicycles, 1 car, 2 traffic lights, 32.7ms
# Speed: 2.5ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bicycles, 1 car, 2 traffic lights, 32.4ms
# Speed: 2.5ms preprocess, 32.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 33.6ms
# Speed: 2.1ms preprocess, 33.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.7ms
# Speed: 2.4ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 1 car, 2 traffic lights, 32.4ms
# Speed: 2.6ms preprocess, 32.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 33.8ms
# Speed: 2.2ms preprocess, 33.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 32.8ms
# Speed: 2.0ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 33.1ms
# Speed: 2.7ms preprocess, 33.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 32.5ms
# Speed: 2.8ms preprocess, 32.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 32.1ms
# Speed: 2.4ms preprocess, 32.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 33.2ms
# Speed: 2.7ms preprocess, 33.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 32.5ms
# Speed: 1.9ms preprocess, 32.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 32.3ms
# Speed: 1.7ms preprocess, 32.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 33.6ms
# Speed: 1.9ms preprocess, 33.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 34.2ms
# Speed: 2.3ms preprocess, 34.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 32.3ms
# Speed: 3.0ms preprocess, 32.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 32.8ms
# Speed: 2.2ms preprocess, 32.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 33.7ms
# Speed: 2.4ms preprocess, 33.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 33.3ms
# Speed: 1.9ms preprocess, 33.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.6ms
# Speed: 2.1ms preprocess, 33.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.5ms
# Speed: 1.8ms preprocess, 33.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 33.3ms
# Speed: 2.0ms preprocess, 33.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 32.6ms
# Speed: 2.6ms preprocess, 32.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 31.8ms
# Speed: 2.6ms preprocess, 31.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 32.1ms
# Speed: 2.0ms preprocess, 32.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 traffic lights, 33.4ms
# Speed: 2.1ms preprocess, 33.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 traffic lights, 33.5ms
# Speed: 2.3ms preprocess, 33.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 traffic lights, 33.2ms
# Speed: 1.9ms preprocess, 33.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.5ms
# Speed: 2.8ms preprocess, 33.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.5ms
# Speed: 2.2ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 32.1ms
# Speed: 2.0ms preprocess, 32.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 32.6ms
# Speed: 2.9ms preprocess, 32.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 3 traffic lights, 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 1 car, 2 traffic lights, 32.7ms
# Speed: 2.1ms preprocess, 32.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 1 car, 2 traffic lights, 32.5ms
# Speed: 2.0ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 2 cars, 2 traffic lights, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 2 cars, 2 traffic lights, 32.7ms
# Speed: 2.0ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.4ms
# Speed: 2.7ms preprocess, 32.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.3ms
# Speed: 2.4ms preprocess, 32.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.4ms
# Speed: 2.6ms preprocess, 32.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 33.5ms
# Speed: 2.9ms preprocess, 33.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 33.0ms
# Speed: 2.2ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 33.6ms
# Speed: 2.6ms preprocess, 33.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 34.3ms
# Speed: 2.9ms preprocess, 34.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 33.9ms
# Speed: 2.3ms preprocess, 33.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 33.0ms
# Speed: 2.1ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 1 bird, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.8ms
# Speed: 2.9ms preprocess, 32.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 1 bird, 40.3ms
# Speed: 1.9ms preprocess, 40.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 32.6ms
# Speed: 2.7ms preprocess, 32.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 2 traffic lights, 33.7ms
# Speed: 3.1ms preprocess, 33.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 31.6ms
# Speed: 1.9ms preprocess, 31.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.2ms
# Speed: 1.9ms preprocess, 33.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 33.1ms
# Speed: 2.9ms preprocess, 33.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 31.7ms
# Speed: 1.9ms preprocess, 31.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 33.0ms
# Speed: 2.2ms preprocess, 33.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 31.3ms
# Speed: 1.9ms preprocess, 31.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 32.0ms
# Speed: 2.1ms preprocess, 32.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.3ms
# Speed: 2.3ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.6ms
# Speed: 2.2ms preprocess, 32.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 traffic lights, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 traffic lights, 31.0ms
# Speed: 2.3ms preprocess, 31.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 traffic lights, 32.4ms
# Speed: 1.8ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 31.3ms
# Speed: 2.0ms preprocess, 31.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 2 cars, 2 traffic lights, 32.0ms
# Speed: 2.2ms preprocess, 32.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 31.7ms
# Speed: 2.2ms preprocess, 31.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 3 cars, 3 traffic lights, 33.3ms
# Speed: 1.9ms preprocess, 33.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 3 traffic lights, 31.8ms
# Speed: 3.0ms preprocess, 31.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 3 traffic lights, 32.5ms
# Speed: 2.5ms preprocess, 32.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 3 traffic lights, 32.6ms
# Speed: 2.1ms preprocess, 32.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 3 traffic lights, 32.0ms
# Speed: 2.3ms preprocess, 32.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 3 traffic lights, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 3 traffic lights, 32.6ms
# Speed: 3.0ms preprocess, 32.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 32.1ms
# Speed: 2.2ms preprocess, 32.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 33.3ms
# Speed: 2.0ms preprocess, 33.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 33.5ms
# Speed: 3.6ms preprocess, 33.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 2 cars, 2 traffic lights, 2 birds, 31.1ms
# Speed: 2.3ms preprocess, 31.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 2 cars, 2 traffic lights, 2 birds, 33.0ms
# Speed: 3.3ms preprocess, 33.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 3 traffic lights, 32.6ms
# Speed: 2.6ms preprocess, 32.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 3 traffic lights, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 3 traffic lights, 32.5ms
# Speed: 2.1ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 3 cars, 3 traffic lights, 30.5ms
# Speed: 2.1ms preprocess, 30.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 3 cars, 3 traffic lights, 33.1ms
# Speed: 3.0ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 32.2ms
# Speed: 2.6ms preprocess, 32.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 33.2ms
# Speed: 1.9ms preprocess, 33.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 33.2ms
# Speed: 1.8ms preprocess, 33.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 1 fire hydrant, 34.2ms
# Speed: 2.6ms preprocess, 34.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 1 fire hydrant, 33.1ms
# Speed: 2.4ms preprocess, 33.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 2 birds, 31.7ms
# Speed: 2.3ms preprocess, 31.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 2 birds, 31.4ms
# Speed: 2.2ms preprocess, 31.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 2 cars, 2 traffic lights, 2 birds, 32.4ms
# Speed: 1.8ms preprocess, 32.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 30.5ms
# Speed: 1.9ms preprocess, 30.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 31.7ms
# Speed: 2.4ms preprocess, 31.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 31.7ms
# Speed: 1.8ms preprocess, 31.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 32.5ms
# Speed: 1.9ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 1 car, 2 traffic lights, 31.3ms
# Speed: 2.2ms preprocess, 31.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 31.5ms
# Speed: 2.7ms preprocess, 31.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 31.2ms
# Speed: 2.0ms preprocess, 31.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 31.8ms
# Speed: 2.2ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 33.2ms
# Speed: 3.0ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 32.4ms
# Speed: 2.4ms preprocess, 32.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 2 traffic lights, 31.9ms
# Speed: 2.4ms preprocess, 31.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 3 traffic lights, 48.9ms
# Speed: 3.0ms preprocess, 48.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 1 car, 3 traffic lights, 31.7ms
# ...
#
# 0: 384x640 1 bicycle, 1 traffic light, 1 stop sign, 33.3ms
# Speed: 2.4ms preprocess, 33.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 traffic light, 1 stop sign, 31.4ms
# Speed: 2.6ms preprocess, 31.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 traffic light, 1 stop sign, 33.7ms
# Speed: 2.3ms preprocess, 33.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 traffic light, 1 stop sign, 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 traffic lights, 1 stop sign, 31.6ms
# Speed: 2.4ms preprocess, 31.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 traffic lights, 1 stop sign, 31.6ms
# Speed: 3.0ms preprocess, 31.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 32.0ms
# Speed: 1.7ms preprocess, 32.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 32.5ms
# Speed: 6.5ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 traffic lights, 1 stop sign, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 traffic lights, 1 stop sign, 31.2ms
# Speed: 2.0ms preprocess, 31.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 traffic lights, 1 stop sign, 32.5ms
# Speed: 2.5ms preprocess, 32.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 traffic lights, 1 stop sign, 32.1ms
# Speed: 2.2ms preprocess, 32.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 traffic lights, 1 stop sign, 45.7ms
# Speed: 2.9ms preprocess, 45.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 2 traffic lights, 1 stop sign, 32.8ms
# Speed: 2.0ms preprocess, 32.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 2 traffic lights, 1 stop sign, 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 34.3ms
# Speed: 4.0ms preprocess, 34.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 31.7ms
# Speed: 2.0ms preprocess, 31.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 35.8ms
# Speed: 2.4ms preprocess, 35.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 36.3ms
# Speed: 2.7ms preprocess, 36.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 41.6ms
# Speed: 2.4ms preprocess, 41.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.0ms
# Speed: 2.2ms preprocess, 33.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 2.5ms preprocess, 31.9ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 35.6ms
# Speed: 2.4ms preprocess, 35.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 35.5ms
# Speed: 2.9ms preprocess, 35.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 32.9ms
# Speed: 2.5ms preprocess, 32.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.5ms
# Speed: 2.7ms preprocess, 32.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 30.2ms
# Speed: 3.2ms preprocess, 30.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.8ms
# Speed: 2.7ms preprocess, 32.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.1ms
# Speed: 2.2ms preprocess, 33.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 traffic light, 1 stop sign, 33.6ms
# Speed: 1.8ms preprocess, 33.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 traffic light, 1 stop sign, 33.5ms
# Speed: 6.9ms preprocess, 33.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 traffic light, 1 stop sign, 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 33.1ms
# Speed: 2.9ms preprocess, 33.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 1 stop sign, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 33.2ms
# Speed: 2.6ms preprocess, 33.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 34.1ms
# Speed: 1.7ms preprocess, 34.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 2 traffic lights, 1 stop sign, 35.4ms
# Speed: 2.2ms preprocess, 35.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 2 traffic lights, 1 stop sign, 34.8ms
# Speed: 2.6ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 truck, 2 traffic lights, 1 stop sign, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 truck, 2 traffic lights, 1 stop sign, 33.3ms
# Speed: 2.0ms preprocess, 33.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 truck, 2 traffic lights, 1 stop sign, 32.3ms
# Speed: 2.7ms preprocess, 32.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 truck, 2 traffic lights, 1 stop sign, 33.7ms
# Speed: 2.1ms preprocess, 33.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 truck, 2 traffic lights, 1 stop sign, 33.1ms
# Speed: 2.7ms preprocess, 33.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 2 traffic lights, 1 stop sign, 52.4ms
# Speed: 2.6ms preprocess, 52.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 2 traffic lights, 1 stop sign, 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 2 traffic lights, 1 stop sign, 32.7ms
# Speed: 2.2ms preprocess, 32.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 3 traffic lights, 1 stop sign, 32.7ms
# Speed: 2.8ms preprocess, 32.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 3 traffic lights, 1 stop sign, 31.2ms
# Speed: 2.8ms preprocess, 31.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 30.8ms
# Speed: 1.8ms preprocess, 30.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 33.7ms
# Speed: 2.9ms preprocess, 33.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 2 traffic lights, 1 stop sign, 33.4ms
# Speed: 2.4ms preprocess, 33.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 1 stop sign, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 3 cars, 1 stop sign, 31.9ms
# Speed: 2.2ms preprocess, 31.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 3 cars, 1 stop sign, 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 3 cars, 1 stop sign, 32.8ms
# Speed: 2.0ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 33.5ms
# Speed: 2.9ms preprocess, 33.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 33.6ms
# Speed: 1.9ms preprocess, 33.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 33.2ms
# Speed: 1.9ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.2ms
# Speed: 2.1ms preprocess, 32.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 32.4ms
# Speed: 4.1ms preprocess, 32.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 traffic light, 1 stop sign, 31.6ms
# Speed: 1.9ms preprocess, 31.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 1 traffic light, 1 stop sign, 32.2ms
# Speed: 2.5ms preprocess, 32.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 31.5ms
# Speed: 2.2ms preprocess, 31.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 31.5ms
# Speed: 1.8ms preprocess, 31.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 33.0ms
# Speed: 2.1ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 1 stop sign, 31.6ms
# Speed: 2.0ms preprocess, 31.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 1 stop sign, 34.0ms
# Speed: 2.1ms preprocess, 34.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 32.4ms
# Speed: 2.1ms preprocess, 32.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 31.8ms
# Speed: 1.8ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 32.9ms
# Speed: 1.8ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 32.3ms
# Speed: 1.8ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 31.6ms
# Speed: 1.9ms preprocess, 31.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 33.3ms
# Speed: 1.8ms preprocess, 33.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 31.5ms
# Speed: 1.6ms preprocess, 31.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 1 stop sign, 48.3ms
# Speed: 1.9ms preprocess, 48.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 1 stop sign, 32.8ms
# Speed: 2.7ms preprocess, 32.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 1 stop sign, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 34.4ms
# Speed: 3.4ms preprocess, 34.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 1 stop sign, 33.8ms
# Speed: 2.7ms preprocess, 33.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 33.1ms
# Speed: 2.4ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 32.7ms
# Speed: 1.8ms preprocess, 32.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 1 car, 32.0ms
# Speed: 2.2ms preprocess, 32.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 2 cars, 2 stop signs, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Annotated video saved to C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_annotated.mp4
# ✅ Final audio saved to C:\Users\tyler\OneDrive\Desktop\Computer Vision\CV Project\Videos\walk_audio.mp3
